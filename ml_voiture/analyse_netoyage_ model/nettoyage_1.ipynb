# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from ydata_profiling import ProfileReport

df = pd.read_csv("voiture_donnees.csv")
pd.set_option('display.max_columns', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# ### Diviser la colonne 'CarName' en deux  --> Supprimer la colonne 'CarName'  --> Réorganiser les colonnes du DataFrame

# %%
# Diviser la colonne 'CarName' en deux
df[['Marque', 'Modele']] = df['CarName'].str.split(' ', n=1, expand=True)
# Supprimer la colonne 'CarName'
df = df.drop(['CarName' ,"car_ID"], axis=1)
# Réorganiser les colonnes du DataFrame
df = df.reindex(columns=['Marque', 'Modele',	"price"	,	"symboling"	,"fueltype",	"aspiration"	,"doornumber"	,"carbody",	"drivewheel"	,"enginelocation",	"wheelbase",	"carlength",	"carwidth"	,"carheight",	"curbweight"	,"enginetype",	"cylindernumber"	,"enginesize",	"fuelsystem",	"boreratio",	"stroke",	"compressionratio"	,"horsepower",	"peakrpm"	,"citympg",	"highwaympg"])


# Afficher le DataFrame résultant
df
# Out:
#           Marque        Modele    price  symboling fueltype aspiration  \
# 0    alfa-romero        giulia  13495.0          3      gas        std
# 1    alfa-romero       stelvio  16500.0          3      gas        std
# 2    alfa-romero  Quadrifoglio  16500.0          1      gas        std
# 3           audi        100 ls  13950.0          2      gas        std
# 4           audi         100ls  17450.0          2      gas        std
# ..           ...           ...      ...        ...      ...        ...
# 200        volvo     145e (sw)  16845.0         -1      gas        std
# 201        volvo         144ea  19045.0         -1      gas      turbo
# 202        volvo         244dl  21485.0         -1      gas        std
# 203        volvo           246  22470.0         -1   diesel      turbo
# 204        volvo         264gl  22625.0         -1      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %% [markdown]
# ### Convertir les colonnes de pouces en cm

# %%
# Convertir les colonnes de pouces en cm
cols = ['wheelbase', 'carlength', 'carwidth', 'carheight']
df[cols] = df[cols].apply(lambda x: x * 0.0254)
df
# Out:
#           Marque        Modele    price  symboling fueltype aspiration  \
# 0    alfa-romero        giulia  13495.0          3      gas        std
# 1    alfa-romero       stelvio  16500.0          3      gas        std
# 2    alfa-romero  Quadrifoglio  16500.0          1      gas        std
# 3           audi        100 ls  13950.0          2      gas        std
# 4           audi         100ls  17450.0          2      gas        std
# ..           ...           ...      ...        ...      ...        ...
# 200        volvo     145e (sw)  16845.0         -1      gas        std
# 201        volvo         144ea  19045.0         -1      gas      turbo
# 202        volvo         244dl  21485.0         -1      gas        std
# 203        volvo           246  22470.0         -1   diesel      turbo
# 204        volvo         264gl  22625.0         -1      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %% [markdown]
# ### Convertir les colonnes de pouces en cm

# %%
# Convertir les colonnes de pouces en cm
cols = ["curbweight"]
df[cols] = df[cols].apply(lambda x: x * 0.454)
df
# Out:
#           Marque        Modele    price  symboling fueltype aspiration  \
# 0    alfa-romero        giulia  13495.0          3      gas        std
# 1    alfa-romero       stelvio  16500.0          3      gas        std
# 2    alfa-romero  Quadrifoglio  16500.0          1      gas        std
# 3           audi        100 ls  13950.0          2      gas        std
# 4           audi         100ls  17450.0          2      gas        std
# ..           ...           ...      ...        ...      ...        ...
# 200        volvo     145e (sw)  16845.0         -1      gas        std
# 201        volvo         144ea  19045.0         -1      gas      turbo
# 202        volvo         244dl  21485.0         -1      gas        std
# 203        volvo           246  22470.0         -1   diesel      turbo
# 204        volvo         264gl  22625.0         -1      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %% [markdown]
# ### Convertir les colonnes de mpg en L/100km

# %%
# Convertir les colonnes de mpg en L/100km
cols = ['citympg', 'highwaympg']
df[cols] = (235.214 / df[cols]).round(2)

# Renommer les colonnes
df = df.rename(columns={'citympg': 'consommation_ville', 'highwaympg': 'consommation_autoroute'})
df
# Out:
#           Marque        Modele    price  symboling fueltype aspiration  \
# 0    alfa-romero        giulia  13495.0          3      gas        std
# 1    alfa-romero       stelvio  16500.0          3      gas        std
# 2    alfa-romero  Quadrifoglio  16500.0          1      gas        std
# 3           audi        100 ls  13950.0          2      gas        std
# 4           audi         100ls  17450.0          2      gas        std
# ..           ...           ...      ...        ...      ...        ...
# 200        volvo     145e (sw)  16845.0         -1      gas        std
# 201        volvo         144ea  19045.0         -1      gas      turbo
# 202        volvo         244dl  21485.0         -1      gas        std
# 203        volvo           246  22470.0         -1   diesel      turbo
# 204        volvo         264gl  22625.0         -1      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %% [markdown]
# ### Convertir la colonne en litres

# %%
# Convertir la colonne en litres
df['enginesize'] = df['enginesize'] * 0.0163871

# Renommer la colonne
df = df.rename(columns={'enginesize': 'litres'})

# %%
df
# Out:
#           Marque        Modele    price  symboling fueltype aspiration  \
# 0    alfa-romero        giulia  13495.0          3      gas        std
# 1    alfa-romero       stelvio  16500.0          3      gas        std
# 2    alfa-romero  Quadrifoglio  16500.0          1      gas        std
# 3           audi        100 ls  13950.0          2      gas        std
# 4           audi         100ls  17450.0          2      gas        std
# ..           ...           ...      ...        ...      ...        ...
# 200        volvo     145e (sw)  16845.0         -1      gas        std
# 201        volvo         144ea  19045.0         -1      gas      turbo
# 202        volvo         244dl  21485.0         -1      gas        std
# 203        volvo           246  22470.0         -1   diesel      turbo
# 204        volvo         264gl  22625.0         -1      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %% [markdown]
# ### Afficher tous les noms uniques dans la colonne 'Marque'

# %%
# Afficher tous les noms uniques dans la colonne 'Marque'
marques_uniques = df['Marque'].unique()
print(marques_uniques)
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'maxda' 'mazda' 'buick' 'mercury' 'mitsubishi' 'Nissan' 'nissan'
#  'peugeot' 'plymouth' 'porsche' 'porcshce' 'renault' 'saab' 'subaru'
#  'toyota' 'toyouta' 'vokswagen' 'volkswagen' 'vw' 'volvo']

# %%
### remplacer les noms mal orthographiés par les noms corrects

# %%
# remplacer les noms mal orthographiés par les noms corrects
df['Marque'] = df['Marque'].replace({'maxda': 'mazda',
                                     'Nissan': 'nissan',
                                     'porcshce': 'porsche',
                                     'toyouta': 'toyota',
                                     'vokswagen': 'volkswagen',
                                     'vw': 'volkswagen'})

# %%
# Afficher tous les noms uniques dans la colonne 'Marque'
marques_uniques = df['Marque'].unique()
print(marques_uniques)
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'buick' 'mercury' 'mitsubishi' 'nissan' 'peugeot' 'plymouth'
#  'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen' 'volvo']

# %%
# Afficher tous les noms uniques dans la colonne 'Marque'
marques_uniques = df['Modele'].unique()
print(marques_uniques)
# Out:
# ['giulia' 'stelvio' 'Quadrifoglio' '100 ls' '100ls' 'fox' '5000' '4000'
#  '5000s (diesel)' '320i' 'x1' 'x3' 'z4' 'x4' 'x5' 'impala' 'monte carlo'
#  'vega 2300' 'rampage' 'challenger se' 'd200' 'monaco (sw)' 'colt hardtop'
#  'colt (sw)' 'coronet custom' 'dart custom' 'coronet custom (sw)' 'civic'
#  'civic cvcc' 'accord cvcc' 'accord lx' 'civic 1500 gl' 'accord'
#  'civic 1300' 'prelude' 'civic (auto)' 'MU-X' 'D-Max ' 'D-Max V-Cross'
#  'xj' 'xf' 'xk' 'rx3' 'glc deluxe' 'rx2 coupe' 'rx-4' '626' 'glc'
#  'rx-7 gs' 'glc 4' 'glc custom l' 'glc custom' 'electra 225 custom'
#  'century luxus (sw)' 'century' 'skyhawk' 'opel isuzu deluxe' 'skylark'
#  'century special' 'regal sport coupe (turbo)' 'cougar' 'mirage' 'lancer'
#  'outlander' 'g4' 'mirage g4' 'montero' 'pajero' 'versa' 'gt-r' 'rogue'
#  'latio' 'titan' 'leaf' 'juke' 'note' 'clipper' 'nv200' 'dayz' 'fuga'
#  'otti' 'teana' 'kicks' '504' '304' '504 (sw)' '604sl' '505s turbo diesel'
# ...

# %% [markdown]
# ### changement des noms

# %%
# remplacer les noms mal orthographiés par les noms corrects
df['Modele'] = df['Modele'].replace({'5000s (diesel)': '5000s',
                                     'monaco (sw)': 'monaco',
                                     'colt (sw)': 'colt',
                                     'coronet custom (sw)': 'coronet custom',
                                     'civic cvcc': 'civic',
                                     'accord cvcc': 'accord',
                                     
                                     'civic 1500 gl': 'civic gl',
                                     'civic 1300': 'civic',
                                     'civic (auto)': 'civic',
                                     'D-Max V-Cross': 'D-Max',
                                     'glc deluxe': 'glc',
                                     'rx2 coupe': 'rx-2',
                                     
                                     'rx-7 gs': 'rx-7',  ###
                                     'glc 4': 'glc',
                                     'glc custom l': 'glc',
                                     'glc custom': 'glc',
                                     'electra 225 custom': 'electra',
                                     'century luxus (sw)': 'century luxus',
                                     
                                     'opel isuzu deluxe': 'deluxe',  
                                     'regal sport coupe (turbo)': 'regal sport coupe',
                                     'mirage g4': 'mirage',
                                     'g4': 'mirage',
                                     '505s turbo diesel': '505s',
                                     '504 (sw)': '504',
                                     
                                     'satellite custom (sw)': 'satellite custom',  
                                     'fury gran sedan': 'fury gran',
                                     'corolla 1600 (sw)': 'corolla 1600',
                                     'corolla liftback': 'corolla',
                                     'celica gt liftback': 'celica gt',
                                     'corolla tercel': 'corolla tercel',
                                     
                                                                          
                                     'corona liftback': 'corona',  
                                     '1131 deluxe sedan': '1131 deluxe ',
                                     '411 (sw)': '411',
                                     '145e (sw)': '145e'
                                     
                                     
                                     
                                     
                                     
                                     
                                     
                                     
                                     })

# %%
# Sélectionner les lignes avec le nom de modèle "5000"
modele_5000 = df.loc[df['Marque'] == 'subaru']

# Afficher les lignes sélectionnées
modele_5000
# Out:
#      Marque   Modele    price  symboling fueltype aspiration doornumber  \
# 138  subaru     None   5118.0          2      gas        std        two
# 139  subaru       dl   7053.0          2      gas        std        two
# 140  subaru       dl   7603.0          2      gas        std        two
# 141  subaru     None   7126.0          0      gas        std       four
# 142  subaru      brz   7775.0          0      gas        std       four
# 143  subaru     baja   9960.0          0      gas        std       four
# 144  subaru       r1   9233.0          0      gas        std       four
# 145  subaru       r2  11259.0          0      gas      turbo       four
# 146  subaru   trezia   7463.0          0      gas        std       four
# 147  subaru  tribeca  10198.0          0      gas        std       four
# 148  subaru       dl   8013.0          0      gas        std       four
# 149  subaru       dl  11694.0          0      gas      turbo       four
#
# ...

# %% [markdown]
# ### Supprimer les lignes avec le modèle "diesel"  &    le modèle "rx-7" et fueltype "diesel"

# %%
# Supprimer les lignes avec le modèle "diesel"
df = df.drop(df[df['Modele'] == 'diesel'].index)


# Sélectionner les lignes avec le modèle "rx-7" et fueltype "diesel"
df = df.drop(df[(df['Modele'] == 'rx-7') & (df['fueltype'] == 'diesel')].index)

df
# Out:
#           Marque        Modele    price  symboling fueltype aspiration  \
# 0    alfa-romero        giulia  13495.0          3      gas        std
# 1    alfa-romero       stelvio  16500.0          3      gas        std
# 2    alfa-romero  Quadrifoglio  16500.0          1      gas        std
# 3           audi        100 ls  13950.0          2      gas        std
# 4           audi         100ls  17450.0          2      gas        std
# ..           ...           ...      ...        ...      ...        ...
# 200        volvo          145e  16845.0         -1      gas        std
# 201        volvo         144ea  19045.0         -1      gas      turbo
# 202        volvo         244dl  21485.0         -1      gas        std
# 203        volvo           246  22470.0         -1   diesel      turbo
# 204        volvo         264gl  22625.0         -1      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %% [markdown]
# ### les voiture qui n'ont pas de modele

# %%
none_models = df[df['Modele'].isnull()]
none_models
# Out:
#      Marque Modele   price  symboling fueltype aspiration doornumber  \
# 138  subaru   None  5118.0          2      gas        std        two
# 141  subaru   None  7126.0          0      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 138  hatchback        fwd          front    2.37998    3.98526   1.61036
# 141      sedan        fwd          front    2.46888    4.36880   1.66116
#
#      carheight  curbweight enginetype cylindernumber    litres fuelsystem  \
# 138    1.36398      930.70       ohcf           four  1.589549       2bbl
# 141    1.33350      973.83       ohcf           four  1.769807       2bbl
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 138       3.62    2.36               9.0          69     4900
# 141       3.62    2.64               9.5          82     4800
#
#      consommation_ville  consommation_autoroute
# 138                7.59                    6.53
# ...

# %% [markdown]
# ### supprimer les lignes dudf où la colonne ‘Modele’ contient la valeur None, vous pouvez utiliser le code suivant:

# %%
df = df.dropna(subset=['Modele'])
df
# Out:
#           Marque        Modele    price  symboling fueltype aspiration  \
# 0    alfa-romero        giulia  13495.0          3      gas        std
# 1    alfa-romero       stelvio  16500.0          3      gas        std
# 2    alfa-romero  Quadrifoglio  16500.0          1      gas        std
# 3           audi        100 ls  13950.0          2      gas        std
# 4           audi         100ls  17450.0          2      gas        std
# ..           ...           ...      ...        ...      ...        ...
# 200        volvo          145e  16845.0         -1      gas        std
# 201        volvo         144ea  19045.0         -1      gas      turbo
# 202        volvo         244dl  21485.0         -1      gas        std
# 203        volvo           246  22470.0         -1   diesel      turbo
# 204        volvo         264gl  22625.0         -1      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %%
# Afficher tous les noms uniques dans la colonne 'Marque'
marques_uniques = df['enginetype'].unique()
print(marques_uniques)
# Out:
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']

# %%
# Sélectionner les lignes avec le nom de modèle "5000"
modele_5000 = df.loc[df['enginetype'] == 'l']

# Afficher les lignes sélectionnées
modele_5000
# Out:
#         Marque  Modele    price  symboling fueltype aspiration doornumber  \
# 18   chevrolet  impala   5151.0          2      gas        std        two
# 107    peugeot     504  11900.0          0      gas        std       four
# 108    peugeot     304  13200.0          0   diesel      turbo       four
# 109    peugeot     504  12440.0          0      gas        std       four
# 110    peugeot     504  13860.0          0   diesel      turbo       four
# 111    peugeot     504  15580.0          0      gas        std       four
# 112    peugeot   604sl  16900.0          0   diesel      turbo       four
# 113    peugeot     504  16695.0          0      gas        std       four
# 114    peugeot    505s  17075.0          0   diesel      turbo       four
# 115    peugeot     504  16630.0          0      gas        std       four
# 116    peugeot     504  17950.0          0   diesel      turbo       four
# 117    peugeot   604sl  18150.0          0      gas      turbo       four
#
# ...

# %%
carbody_dict = {'convertible': 'cabriolet', 'hatchback': 'hayon', 'sedan': 'berline', 'wagon': 'break', 'hardtop': 'coupe'}
df.loc[:, 'carbody'] = df['carbody'].replace(carbody_dict)
df
# Out:
# C:\Users\impej\AppData\Local\Temp\ipykernel_22240\802083781.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'carbody'] = df['carbody'].replace(carbody_dict)
#           Marque        Modele    price  symboling fueltype aspiration  \
# 0    alfa-romero        giulia  13495.0          3      gas        std
# 1    alfa-romero       stelvio  16500.0          3      gas        std
# 2    alfa-romero  Quadrifoglio  16500.0          1      gas        std
# 3           audi        100 ls  13950.0          2      gas        std
# 4           audi         100ls  17450.0          2      gas        std
# ..           ...           ...      ...        ...      ...        ...
# ...

# %%
drivewheel_dict = {'rwd': 'propulsion', 'fwd': 'traction', '4wd': 'quatre roues motrices'}
df['drivewheel'] = df['drivewheel'].replace(drivewheel_dict)
df
# Out:
# C:\Users\impej\AppData\Local\Temp\ipykernel_22240\3374462672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['drivewheel'] = df['drivewheel'].replace(drivewheel_dict)
#           Marque        Modele    price  symboling fueltype aspiration  \
# 0    alfa-romero        giulia  13495.0          3      gas        std
# 1    alfa-romero       stelvio  16500.0          3      gas        std
# 2    alfa-romero  Quadrifoglio  16500.0          1      gas        std
# 3           audi        100 ls  13950.0          2      gas        std
# 4           audi         100ls  17450.0          2      gas        std
# ..           ...           ...      ...        ...      ...        ...
# ...

# %%
enginelocation_dict = {'front': 'avant', 'rear': 'arriere'}
df['enginelocation'] = df['enginelocation'].replace(enginelocation_dict)
df = df.rename(columns={'enginelocation': 'emplacement_moteur'})
df
# Out:
# C:\Users\impej\AppData\Local\Temp\ipykernel_22240\2750538084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['enginelocation'] = df['enginelocation'].replace(enginelocation_dict)
#           Marque        Modele    price  symboling fueltype aspiration  \
# 0    alfa-romero        giulia  13495.0          3      gas        std
# 1    alfa-romero       stelvio  16500.0          3      gas        std
# 2    alfa-romero  Quadrifoglio  16500.0          1      gas        std
# 3           audi        100 ls  13950.0          2      gas        std
# 4           audi         100ls  17450.0          2      gas        std
# ..           ...           ...      ...        ...      ...        ...
# ...

# %%
df = df.rename(columns={
    'Marque': 'marque',
    'Modele': 'modele',
    'price': 'prix',
    'symboling': 'risque_assurance',
    'fueltype': 'type_de_carburant',
    'aspiration': 'aspiration',
    'doornumber': 'nombre_de_portes',
    'carbody': 'carrosserie',
    'drivewheel': 'roues_motrices',
    'emplacement_moteur': 'emplacement_moteur',
    'wheelbase': 'empattement',
    'carlength': 'longueur_voiture',
    'carwidth': 'largeur_voiture',
    'carheight': 'hauteur_voiture',
    'curbweight': 'poids_à_vide',
    'enginetype': 'type_de_moteur',
    'cylindernumber': 'nombre_de_cylindres',
    'litres': 'taille_moteur_en_litres',
    'fuelsystem': 'système_de_carburant',
    'boreratio': 'alésage',
    'stroke': 'course',
    'compressionratio': 'taux_de_compression',
    'horsepower': 'puissance',
    'peakrpm': 'rpm_max'
    
})

# %%
df
# Out:
#           marque        modele     prix  risque_assurance type_de_carburant  \
# 0    alfa-romero        giulia  13495.0                 3               gas
# 1    alfa-romero       stelvio  16500.0                 3               gas
# 2    alfa-romero  Quadrifoglio  16500.0                 1               gas
# 3           audi        100 ls  13950.0                 2               gas
# 4           audi         100ls  17450.0                 2               gas
# ..           ...           ...      ...               ...               ...
# 200        volvo          145e  16845.0                -1               gas
# 201        volvo         144ea  19045.0                -1               gas
# 202        volvo         244dl  21485.0                -1               gas
# 203        volvo           246  22470.0                -1            diesel
# 204        volvo         264gl  22625.0                -1               gas
#
# ...

# %%
# Afficher tous les noms uniques dans la colonne 'Marque'
marques_uniques = df['nombre_de_cylindres'].unique()
print(marques_uniques)
# Out:
# ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']

# %%
df['nombre_de_cylindres'] = df['nombre_de_cylindres'].replace(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'], [4, 6, 5, 3, 12, 2, 8])
df
# Out:
#           marque        modele     prix  risque_assurance type_de_carburant  \
# 0    alfa-romero        giulia  13495.0                 3               gas
# 1    alfa-romero       stelvio  16500.0                 3               gas
# 2    alfa-romero  Quadrifoglio  16500.0                 1               gas
# 3           audi        100 ls  13950.0                 2               gas
# 4           audi         100ls  17450.0                 2               gas
# ..           ...           ...      ...               ...               ...
# 200        volvo          145e  16845.0                -1               gas
# 201        volvo         144ea  19045.0                -1               gas
# 202        volvo         244dl  21485.0                -1               gas
# 203        volvo           246  22470.0                -1            diesel
# 204        volvo         264gl  22625.0                -1               gas
#
# ...

# %%
df['type_de_carburant'] = df['type_de_carburant'].replace(['gas', 'diesel'], ['essence', 'diesel'])
df['système_de_carburant'] = df['système_de_carburant'].replace(["spfi"], ["spdi"])

df
# Out:
#           marque        modele     prix  risque_assurance type_de_carburant  \
# 0    alfa-romero        giulia  13495.0                 3           essence
# 1    alfa-romero       stelvio  16500.0                 3           essence
# 2    alfa-romero  Quadrifoglio  16500.0                 1           essence
# 3           audi        100 ls  13950.0                 2           essence
# 4           audi         100ls  17450.0                 2           essence
# ..           ...           ...      ...               ...               ...
# 200        volvo          145e  16845.0                -1           essence
# 201        volvo         144ea  19045.0                -1           essence
# 202        volvo         244dl  21485.0                -1           essence
# 203        volvo           246  22470.0                -1            diesel
# 204        volvo         264gl  22625.0                -1           essence
#
# ...

# %%
df['nombre_de_portes'] = df['nombre_de_portes'].replace(['two', 'four'], [2, 4])
df
# Out:
#           marque        modele     prix  risque_assurance type_de_carburant  \
# 0    alfa-romero        giulia  13495.0                 3           essence
# 1    alfa-romero       stelvio  16500.0                 3           essence
# 2    alfa-romero  Quadrifoglio  16500.0                 1           essence
# 3           audi        100 ls  13950.0                 2           essence
# 4           audi         100ls  17450.0                 2           essence
# ..           ...           ...      ...               ...               ...
# 200        volvo          145e  16845.0                -1           essence
# 201        volvo         144ea  19045.0                -1           essence
# 202        volvo         244dl  21485.0                -1           essence
# 203        volvo           246  22470.0                -1            diesel
# 204        volvo         264gl  22625.0                -1           essence
#
# ...

# %% [markdown]
# ### remplacement des erreur ['ohcf', 'dohcv'] par ['ohc', 'dohc']

# %%
df['type_de_moteur'] = df['type_de_moteur'].replace(['ohcf', 'dohcv'], ['ohc', 'dohc'])

# %% [markdown]
# ### création du nouveau CSV

# %%
df.to_csv("donnees_propre.csv" , index=False)

# %%
# fig, ax = plt.subplots(figsize=(5,12))
# sns.heatmap(df.corr(numeric_only = True)[["prix"]].sort_values('prix'), vmax=1, vmin=-1, cmap='Reds', annot=True, ax=ax)
# ax.invert_yaxis()
